# %% [markdown]
# # VODER + Cloudflare + Telegram
# 1. فعّل Internet وGPU.
# 2. أضف `VODER_BRIDGE_TOKEN` في Add-ons → Secrets.
# 3. ارفع `KAGGLE_SETUP.py` و`voder_colab_bridge.py` من مجلد Dropbox `/VODER` إلى `/kaggle/working`.
# 4. شغّل الخلية التالية واتركها تعمل.

# %%
# %run /kaggle/working/KAGGLE_SETUP.py

# %% [markdown]
# بعد ظهور `VODER bridge started`، أرسل ملفًا صوتيًا أو فيديو إلى بوت Telegram. ستصل النتيجة إلى نفس المحادثة.

# %%
# للإيقاف عند الحاجة
# !pkill -f voder_colab_bridge.py || true
